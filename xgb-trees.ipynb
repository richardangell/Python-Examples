# %%
import xgboost as xgb
import numpy as np
import pandas as pd

# %%
#  this script demonstrates how to fit gamma regression model (with log link function)
#  in xgboost, before running the demo you need to generate the autoclaims dataset
#  by running gen_autoclaims.R located in xgboost/demo/data.

data = np.genfromtxt('/Users/richardangell/Projects/xgboost/demo/data/autoclaims.csv', delimiter=',')
dtrain = xgb.DMatrix(data[0:4741, 0:34], data[0:4741, 34])
dtest = xgb.DMatrix(data[4741:6773, 0:34], data[4741:6773, 34])

# for gamma regression, we need to set the objective to 'reg:gamma', it also suggests
# to set the base_score to a value between 1 to 5 if the number of iteration is small
param = {'silent':1, 'objective':'reg:gamma', 'booster':'gbtree', 'max_depth': 6, 'base_score': 3}

# the rest of settings are the same
watchlist = [(dtest, 'eval'), (dtrain, 'train')]
num_round = 100

# training and evaluation
bst = xgb.train(param, dtrain, num_round, watchlist)
preds = bst.predict(dtest)
labels = dtest.get_label()
print('test deviance=%f' % (2 * np.sum((labels - preds) / preds - np.log(labels) + np.log(preds))))
# Out:
# [0]	eval-gamma-nloglik:474.955	train-gamma-nloglik:452.463
# [1]	eval-gamma-nloglik:352.75	train-gamma-nloglik:336.077
# [2]	eval-gamma-nloglik:262.296	train-gamma-nloglik:249.934
# [3]	eval-gamma-nloglik:195.364	train-gamma-nloglik:186.194
# [4]	eval-gamma-nloglik:145.856	train-gamma-nloglik:139.052
# [5]	eval-gamma-nloglik:109.256	train-gamma-nloglik:104.205
# [6]	eval-gamma-nloglik:82.2192	train-gamma-nloglik:78.4658
# [7]	eval-gamma-nloglik:62.2658	train-gamma-nloglik:59.474
# [8]	eval-gamma-nloglik:47.5594	train-gamma-nloglik:45.4801
# [9]	eval-gamma-nloglik:36.7394	train-gamma-nloglik:35.1879
# [10]	eval-gamma-nloglik:28.7975	train-gamma-nloglik:27.637
# [11]	eval-gamma-nloglik:22.9865	train-gamma-nloglik:22.1154
# [12]	eval-gamma-nloglik:18.7522	train-gamma-nloglik:18.0955
# [13]	eval-gamma-nloglik:15.6839	train-gamma-nloglik:15.1858
# [14]	eval-gamma-nloglik:13.4628	train-gamma-nloglik:13.0951
# [15]	eval-gamma-nloglik:11.8812	train-gamma-nloglik:11.6075
# [16]	eval-gamma-nloglik:10.768	train-gamma-nloglik:10.5618
# [17]	eval-gamma-nloglik:9.99775	train-gamma-nloglik:9.83801
# [18]	eval-gamma-nloglik:9.4729	train-gamma-nloglik:9.34576
# [19]	eval-gamma-nloglik:9.12468	train-gamma-nloglik:9.01853
# [20]	eval-gamma-nloglik:8.89895	train-gamma-nloglik:8.804
# [21]	eval-gamma-nloglik:8.76124	train-gamma-nloglik:8.66933
# [22]	eval-gamma-nloglik:8.67696	train-gamma-nloglik:8.58366
# [23]	eval-gamma-nloglik:8.63137	train-gamma-nloglik:8.53351
# [24]	eval-gamma-nloglik:8.61182	train-gamma-nloglik:8.50134
# [25]	eval-gamma-nloglik:8.59519	train-gamma-nloglik:8.48189
# [26]	eval-gamma-nloglik:8.59219	train-gamma-nloglik:8.46911
# [27]	eval-gamma-nloglik:8.58696	train-gamma-nloglik:8.45834
# [28]	eval-gamma-nloglik:8.58519	train-gamma-nloglik:8.45287
# [29]	eval-gamma-nloglik:8.58761	train-gamma-nloglik:8.44937
# [30]	eval-gamma-nloglik:8.5893	train-gamma-nloglik:8.44522
# [31]	eval-gamma-nloglik:8.59028	train-gamma-nloglik:8.44061
# [32]	eval-gamma-nloglik:8.59247	train-gamma-nloglik:8.43821
# [33]	eval-gamma-nloglik:8.60197	train-gamma-nloglik:8.43465
# [34]	eval-gamma-nloglik:8.61331	train-gamma-nloglik:8.43107
# [35]	eval-gamma-nloglik:8.61499	train-gamma-nloglik:8.42604
# [36]	eval-gamma-nloglik:8.61651	train-gamma-nloglik:8.42519
# [37]	eval-gamma-nloglik:8.62455	train-gamma-nloglik:8.4204
# [38]	eval-gamma-nloglik:8.62474	train-gamma-nloglik:8.41957
# [39]	eval-gamma-nloglik:8.62471	train-gamma-nloglik:8.41668
# [40]	eval-gamma-nloglik:8.63577	train-gamma-nloglik:8.41429
# [41]	eval-gamma-nloglik:8.63957	train-gamma-nloglik:8.40977
# [42]	eval-gamma-nloglik:8.65223	train-gamma-nloglik:8.40565
# [43]	eval-gamma-nloglik:8.65125	train-gamma-nloglik:8.40529
# [44]	eval-gamma-nloglik:8.65171	train-gamma-nloglik:8.40389
# [45]	eval-gamma-nloglik:8.65668	train-gamma-nloglik:8.40043
# [46]	eval-gamma-nloglik:8.65791	train-gamma-nloglik:8.39884
# [47]	eval-gamma-nloglik:8.67127	train-gamma-nloglik:8.39626
# [48]	eval-gamma-nloglik:8.6743	train-gamma-nloglik:8.39537
# [49]	eval-gamma-nloglik:8.67449	train-gamma-nloglik:8.39162
# [50]	eval-gamma-nloglik:8.67626	train-gamma-nloglik:8.38751
# [51]	eval-gamma-nloglik:8.67548	train-gamma-nloglik:8.38629
# [52]	eval-gamma-nloglik:8.67609	train-gamma-nloglik:8.3842
# [53]	eval-gamma-nloglik:8.67576	train-gamma-nloglik:8.3819
# [54]	eval-gamma-nloglik:8.68572	train-gamma-nloglik:8.38068
# [55]	eval-gamma-nloglik:8.68575	train-gamma-nloglik:8.37786
# [56]	eval-gamma-nloglik:8.68857	train-gamma-nloglik:8.3774
# [57]	eval-gamma-nloglik:8.6888	train-gamma-nloglik:8.37694
# [58]	eval-gamma-nloglik:8.69468	train-gamma-nloglik:8.37561
# [59]	eval-gamma-nloglik:8.69447	train-gamma-nloglik:8.37348
# [60]	eval-gamma-nloglik:8.69441	train-gamma-nloglik:8.37176
# [61]	eval-gamma-nloglik:8.69794	train-gamma-nloglik:8.3691
# [62]	eval-gamma-nloglik:8.69829	train-gamma-nloglik:8.36747
# [63]	eval-gamma-nloglik:8.71068	train-gamma-nloglik:8.36606
# [64]	eval-gamma-nloglik:8.71412	train-gamma-nloglik:8.36459
# [65]	eval-gamma-nloglik:8.73177	train-gamma-nloglik:8.36292
# [66]	eval-gamma-nloglik:8.73157	train-gamma-nloglik:8.36212
# [67]	eval-gamma-nloglik:8.73991	train-gamma-nloglik:8.36099
# [68]	eval-gamma-nloglik:8.74462	train-gamma-nloglik:8.35915
# [69]	eval-gamma-nloglik:8.74351	train-gamma-nloglik:8.35706
# [70]	eval-gamma-nloglik:8.74369	train-gamma-nloglik:8.35636
# [71]	eval-gamma-nloglik:8.74652	train-gamma-nloglik:8.3543
# [72]	eval-gamma-nloglik:8.7465	train-gamma-nloglik:8.35371
# [73]	eval-gamma-nloglik:8.74664	train-gamma-nloglik:8.35168
# [74]	eval-gamma-nloglik:8.74854	train-gamma-nloglik:8.35019
# [75]	eval-gamma-nloglik:8.75175	train-gamma-nloglik:8.34765
# [76]	eval-gamma-nloglik:8.75175	train-gamma-nloglik:8.34649
# [77]	eval-gamma-nloglik:8.75988	train-gamma-nloglik:8.34477
# [78]	eval-gamma-nloglik:8.76168	train-gamma-nloglik:8.34296
# [79]	eval-gamma-nloglik:8.76131	train-gamma-nloglik:8.34262
# [80]	eval-gamma-nloglik:8.76152	train-gamma-nloglik:8.34202
# [81]	eval-gamma-nloglik:8.76339	train-gamma-nloglik:8.34137
# [82]	eval-gamma-nloglik:8.77062	train-gamma-nloglik:8.33919
# [83]	eval-gamma-nloglik:8.77867	train-gamma-nloglik:8.33765
# [84]	eval-gamma-nloglik:8.77868	train-gamma-nloglik:8.3358
# [85]	eval-gamma-nloglik:8.77841	train-gamma-nloglik:8.33482
# [86]	eval-gamma-nloglik:8.78005	train-gamma-nloglik:8.33358
# [87]	eval-gamma-nloglik:8.78264	train-gamma-nloglik:8.33166
# [88]	eval-gamma-nloglik:8.78312	train-gamma-nloglik:8.32961
# [89]	eval-gamma-nloglik:8.783	train-gamma-nloglik:8.32827
# [90]	eval-gamma-nloglik:8.78254	train-gamma-nloglik:8.3266
# [91]	eval-gamma-nloglik:8.78352	train-gamma-nloglik:8.32604
# [92]	eval-gamma-nloglik:8.78562	train-gamma-nloglik:8.32564
# [93]	eval-gamma-nloglik:8.78534	train-gamma-nloglik:8.32483
# [94]	eval-gamma-nloglik:8.7854	train-gamma-nloglik:8.32416
# [95]	eval-gamma-nloglik:8.78681	train-gamma-nloglik:8.32281
# [96]	eval-gamma-nloglik:8.78851	train-gamma-nloglik:8.32218
# [97]	eval-gamma-nloglik:8.78514	train-gamma-nloglik:8.32024
# [98]	eval-gamma-nloglik:8.78808	train-gamma-nloglik:8.31887
# [99]	eval-gamma-nloglik:8.79051	train-gamma-nloglik:8.31809
# test deviance=3107.594482

# %%
bst.dump_model('model_dump_test.txt', with_stats = True)

# %%
def read_dump(file):
    """
    Reads an xgboost model dump .txt file and parses it into a tabular structure.
    :param file: xgboost model dump .txt file
    :return: pd.DataFrame, with columns tree, node, left, right, missing, split_var, split_point, prediction
    """
    with open(file) as f:

        lines = f.readlines()
    
    tree_no = -1
    
    lines_list = []
    
    for i in range(len(lines)):
        
        # if line is a new tree
        if lines[i][:7] == 'booster':
            
            tree_no += 1
        
        # else if node row
        else:
        
            line_dict = {}
        
            # remove \n from end and any \t from start
            node_str = lines[i][:len(lines[i])-1].replace('\t', '')
            
            line_dict['tree'] = tree_no
            
            # split by :
            node_str_split1 = node_str.split(':')
            
            # get the node number before the :
            line_dict['node'] = int(node_str_split1[0])

            # else if leaf node
            if node_str_split1[1][:4]  == 'leaf':
                
                node_str_split2 = node_str_split1[1].split(',')
                
                line_dict['quality'] = float(node_str_split2[0].split('=')[1])
                line_dict['cover'] = float(node_str_split2[1].split('=')[1])

            # else non terminal node
            else:
                
                node_str_split2 = node_str_split1[1].split(' ')
                
                node_str_split3 = node_str_split2[0].replace('[', '').replace(']', '').split('<')
                
                # extract split variable name before the <
                line_dict['split_var'] = node_str_split3[0]

                # extract split point after the <
                line_dict['split_point'] = float(node_str_split3[1])
  
                node_str_split4 = node_str_split2[1].split(',')
                
                # get the child nodes
                line_dict['yes'] = int(node_str_split4[0].split('=')[1])
                line_dict['no'] = int(node_str_split4[1].split('=')[1])
                line_dict['missing'] = int(node_str_split4[2].split('=')[1])
                
                # get the child nodes
                # note quality = gain
                line_dict['quality'] = float(node_str_split4[3].split('=')[1])
                line_dict['cover'] = float(node_str_split4[4].split('=')[1])

            lines_list = lines_list + [line_dict]
    
    lines_df = pd.DataFrame.from_dict(lines_list)
    
    col_order = ['tree', 'node', 'yes', 'no', 'missing', 'split_var', 'split_point','quality', 'cover']
    
    # reorder columns
    lines_df = lines_df.loc[:,col_order]
    
    lines_df.sort_values(['tree', 'node'], inplace = True)
    
    return(lines, lines_df)

# %%
lines, model_structure = read_dump('model_dump_test.txt')

# %%
model_structure.head(20)
# Out:
#     tree  node  yes   no  missing split_var  split_point   quality  \
# 0      0     0  NaN  NaN      NaN       NaN          NaN  0.299507
# 1      1     0  NaN  NaN      NaN       NaN          NaN  0.299335
# 2      2     0  NaN  NaN      NaN       NaN          NaN  0.299103
# 3      3     0  NaN  NaN      NaN       NaN          NaN  0.298790
# 4      4     0  NaN  NaN      NaN       NaN          NaN  0.298368
# 5      5     0  NaN  NaN      NaN       NaN          NaN  0.297801
# 6      6     0  NaN  NaN      NaN       NaN          NaN  0.297038
# 7      7     0  NaN  NaN      NaN       NaN          NaN  0.296014
# 8      8     0  NaN  NaN      NaN       NaN          NaN  0.294641
# 9      9     0  NaN  NaN      NaN       NaN          NaN  0.292804
# 10    10     0  NaN  NaN      NaN       NaN          NaN  0.290357
# 11    11     0  1.0  2.0      1.0       f29          0.5  0.093750
# 12    11     1  NaN  NaN      NaN       NaN          NaN  0.287167
# 13    11     2  NaN  NaN      NaN       NaN          NaN  0.273858
# 14    12     0  1.0  2.0      1.0       f29          0.5  0.406250
# 15    12     1  NaN  NaN      NaN       NaN          NaN  0.282899
# 16    12     2  NaN  NaN      NaN       NaN          NaN  0.265643
# 17    13     0  1.0  2.0      1.0       f29          0.5  0.773438
# 18    13     1  3.0  4.0      3.0       f33         81.5  0.316406
# 23    13     2  NaN  NaN      NaN       NaN          NaN  0.255224
#
#            cover
# 0   2.885251e+06
# 1   2.138500e+06
# 2   1.585294e+06
# 3   1.175469e+06
# 4   8.718635e+05
# 5   6.469472e+05
# 6   4.803253e+05
# 7   3.568892e+05
# 8   2.654460e+05
# 9   1.977039e+05
# 10  1.475204e+05
# 11  1.103448e+05
# 12  1.098294e+05
# 13  5.154083e+02
# 14  8.280636e+04
# 15  8.241442e+04
# 16  3.919371e+02
# 17  6.240768e+04
# 18  6.210718e+04
# 23  3.005031e+02

# %%
base_score = np.log(3)

# %%
model_structure['weight'] = 0

# %%
model_structure.loc[model_structure.split_var.isnull(), 'weight'] = base_score + \
    model_structure.loc[model_structure.split_var.isnull(), 'quality']

# %%
model_structure['H'] = model_structure['cover']

# %%
model_structure['G'] = 0

# %%
model_structure.loc[model_structure.split_var.isnull(), 'G'] = \
    - model_structure.loc[model_structure.split_var.isnull(), 'weight'] * \
    model_structure.loc[model_structure.split_var.isnull(), 'H']

# %%
model_structure.reset_index(inplace = True)

# %%
model_structure['node_type'] = 'internal'
model_structure.loc[model_structure.split_point.isnull(), 'node_type'] = 'leaf'

# %%
model_structure.head(26)
# Out:
#     index  tree  node  yes   no  missing split_var  split_point   quality  \
# 0       0     0     0  NaN  NaN      NaN       NaN          NaN  0.299507
# 1       1     1     0  NaN  NaN      NaN       NaN          NaN  0.299335
# 2       2     2     0  NaN  NaN      NaN       NaN          NaN  0.299103
# 3       3     3     0  NaN  NaN      NaN       NaN          NaN  0.298790
# 4       4     4     0  NaN  NaN      NaN       NaN          NaN  0.298368
# 5       5     5     0  NaN  NaN      NaN       NaN          NaN  0.297801
# 6       6     6     0  NaN  NaN      NaN       NaN          NaN  0.297038
# 7       7     7     0  NaN  NaN      NaN       NaN          NaN  0.296014
# 8       8     8     0  NaN  NaN      NaN       NaN          NaN  0.294641
# 9       9     9     0  NaN  NaN      NaN       NaN          NaN  0.292804
# 10     10    10     0  NaN  NaN      NaN       NaN          NaN  0.290357
# 11     11    11     0  1.0  2.0      1.0       f29          0.5  0.093750
# 12     12    11     1  NaN  NaN      NaN       NaN          NaN  0.287167
# 13     13    11     2  NaN  NaN      NaN       NaN          NaN  0.273858
# 14     14    12     0  1.0  2.0      1.0       f29          0.5  0.406250
# 15     15    12     1  NaN  NaN      NaN       NaN          NaN  0.282899
# 16     16    12     2  NaN  NaN      NaN       NaN          NaN  0.265643
# 17     17    13     0  1.0  2.0      1.0       f29          0.5  0.773438
# 18     18    13     1  3.0  4.0      3.0       f33         81.5  0.316406
# 19     23    13     2  NaN  NaN      NaN       NaN          NaN  0.255224
# 20     19    13     3  5.0  6.0      5.0       f24          0.5  0.464844
# 21     22    13     4  NaN  NaN      NaN       NaN          NaN  0.280800
# 22     20    13     5  NaN  NaN      NaN       NaN          NaN  0.276335
# 23     21    13     6  NaN  NaN      NaN       NaN          NaN  0.281357
# 24     24    14     0  1.0  2.0      1.0       f29          0.5  1.187500
# 25     25    14     1  3.0  4.0      3.0       f33         81.5  0.675781
#
#            cover    weight             H             G node_type
# 0   2.885251e+06  1.398119  2.885251e+06 -4.033925e+06      leaf
# 1   2.138500e+06  1.397947  2.138500e+06 -2.989511e+06      leaf
# 2   1.585294e+06  1.397715  1.585294e+06 -2.215790e+06      leaf
# 3   1.175469e+06  1.397402  1.175469e+06 -1.642603e+06      leaf
# 4   8.718635e+05  1.396981  8.718635e+05 -1.217976e+06      leaf
# 5   6.469472e+05  1.396413  6.469472e+05 -9.034057e+05      leaf
# 6   4.803253e+05  1.395651  4.803253e+05 -6.703663e+05      leaf
# 7   3.568892e+05  1.394626  3.568892e+05 -4.977270e+05      leaf
# 8   2.654460e+05  1.393253  2.654460e+05 -3.698335e+05      leaf
# 9   1.977039e+05  1.391417  1.977039e+05 -2.750886e+05      leaf
# 10  1.475204e+05  1.388969  1.475204e+05 -2.049013e+05      leaf
# 11  1.103448e+05  0.000000  1.103448e+05  0.000000e+00  internal
# 12  1.098294e+05  1.385780  1.098294e+05 -1.521993e+05      leaf
# 13  5.154083e+02  1.372470  5.154083e+02 -7.073825e+02      leaf
# 14  8.280636e+04  0.000000  8.280636e+04  0.000000e+00  internal
# 15  8.241442e+04  1.381511  8.241442e+04 -1.138564e+05      leaf
# 16  3.919371e+02  1.364256  3.919371e+02 -5.347024e+02      leaf
# 17  6.240768e+04  0.000000  6.240768e+04  0.000000e+00  internal
# 18  6.210718e+04  0.000000  6.210718e+04  0.000000e+00  internal
# 19  3.005031e+02  1.353837  3.005031e+02 -4.068321e+02      leaf
# 20  5.453003e+04  0.000000  5.453003e+04  0.000000e+00  internal
# 21  7.577151e+03  1.379412  7.577151e+03 -1.045202e+04      leaf
# 22  4.934934e+04  1.374947  4.934934e+04 -6.785272e+04      leaf
# 23  5.180688e+03  1.379970  5.180688e+03 -7.149193e+03      leaf
# 24  4.729947e+04  0.000000  4.729947e+04  0.000000e+00  internal
# 25  4.706666e+04  0.000000  4.706666e+04  0.000000e+00  internal

# %%
#xx = model_structure.loc[model_structure.tree == 13].copy()
#xx

# %%
#aa= single_tree_fill(xx)

# %%
def single_tree_fill(df):
    
    df = df.copy()
    
    leaf_df = df.loc[df.node_type == 'leaf']
    
    # loop through each leaf node
    for i in leaf_df.index:
        
        #print(i, 'leaf---------------')
        
        leaf_row = leaf_df.loc[[i]]
        
        current_node = leaf_row['node'].item()
        
        leaf_G = leaf_row['G'].item()
        
        #print('current_node', current_node)
        #print(df)
        #print('---')
        
        if current_node > 0:
        
            # traverse the tree bottom to top and propogate the G values upwards
            while True:

                parent = (df.yes == current_node) | (df.no == current_node)

                df.loc[parent, 'G'] = df.loc[parent, 'G'] + leaf_G

                leaf_row = df.loc[parent]

                current_node = leaf_row['node'].item()            

                #print('current_node', current_node)
                #print(df)
                #print('---')

                if current_node == 0:

                    break
                
    return(df)

# %%
trees = model_structure.tree.max()
trees
# Out:
# 99

# %%
new_trees = model_structure.loc[model_structure.tree == -1]
for n in range(trees + 1):
    tree_df = model_structure.loc[model_structure.tree == n]
    new_trees

# %%
new_trees = [single_tree_fill(model_structure.loc[model_structure.tree == n]) for n in range(trees + 1)]

# %%
model_structure2 = pd.concat(new_trees, axis = 0)

# %%
model_structure.shape
# Out:
# (6766, 14)

# %%
model_structure2.shape
# Out:
# (6766, 14)

# %%
model_structure2.head(26)
# Out:
#     index  tree  node  yes   no  missing split_var  split_point   quality  \
# 0       0     0     0  NaN  NaN      NaN       NaN          NaN  0.299507
# 1       1     1     0  NaN  NaN      NaN       NaN          NaN  0.299335
# 2       2     2     0  NaN  NaN      NaN       NaN          NaN  0.299103
# 3       3     3     0  NaN  NaN      NaN       NaN          NaN  0.298790
# 4       4     4     0  NaN  NaN      NaN       NaN          NaN  0.298368
# 5       5     5     0  NaN  NaN      NaN       NaN          NaN  0.297801
# 6       6     6     0  NaN  NaN      NaN       NaN          NaN  0.297038
# 7       7     7     0  NaN  NaN      NaN       NaN          NaN  0.296014
# 8       8     8     0  NaN  NaN      NaN       NaN          NaN  0.294641
# 9       9     9     0  NaN  NaN      NaN       NaN          NaN  0.292804
# 10     10    10     0  NaN  NaN      NaN       NaN          NaN  0.290357
# 11     11    11     0  1.0  2.0      1.0       f29          0.5  0.093750
# 12     12    11     1  NaN  NaN      NaN       NaN          NaN  0.287167
# 13     13    11     2  NaN  NaN      NaN       NaN          NaN  0.273858
# 14     14    12     0  1.0  2.0      1.0       f29          0.5  0.406250
# 15     15    12     1  NaN  NaN      NaN       NaN          NaN  0.282899
# 16     16    12     2  NaN  NaN      NaN       NaN          NaN  0.265643
# 17     17    13     0  1.0  2.0      1.0       f29          0.5  0.773438
# 18     18    13     1  3.0  4.0      3.0       f33         81.5  0.316406
# 19     23    13     2  NaN  NaN      NaN       NaN          NaN  0.255224
# 20     19    13     3  5.0  6.0      5.0       f24          0.5  0.464844
# 21     22    13     4  NaN  NaN      NaN       NaN          NaN  0.280800
# 22     20    13     5  NaN  NaN      NaN       NaN          NaN  0.276335
# 23     21    13     6  NaN  NaN      NaN       NaN          NaN  0.281357
# 24     24    14     0  1.0  2.0      1.0       f29          0.5  1.187500
# 25     25    14     1  3.0  4.0      3.0       f33         81.5  0.675781
#
#            cover    weight             H             G node_type
# 0   2.885251e+06  1.398119  2.885251e+06 -4.033925e+06      leaf
# 1   2.138500e+06  1.397947  2.138500e+06 -2.989511e+06      leaf
# 2   1.585294e+06  1.397715  1.585294e+06 -2.215790e+06      leaf
# 3   1.175469e+06  1.397402  1.175469e+06 -1.642603e+06      leaf
# 4   8.718635e+05  1.396981  8.718635e+05 -1.217976e+06      leaf
# 5   6.469472e+05  1.396413  6.469472e+05 -9.034057e+05      leaf
# 6   4.803253e+05  1.395651  4.803253e+05 -6.703663e+05      leaf
# 7   3.568892e+05  1.394626  3.568892e+05 -4.977270e+05      leaf
# 8   2.654460e+05  1.393253  2.654460e+05 -3.698335e+05      leaf
# 9   1.977039e+05  1.391417  1.977039e+05 -2.750886e+05      leaf
# 10  1.475204e+05  1.388969  1.475204e+05 -2.049013e+05      leaf
# 11  1.103448e+05  0.000000  1.103448e+05 -1.529067e+05  internal
# 12  1.098294e+05  1.385780  1.098294e+05 -1.521993e+05      leaf
# 13  5.154083e+02  1.372470  5.154083e+02 -7.073825e+02      leaf
# 14  8.280636e+04  0.000000  8.280636e+04 -1.143911e+05  internal
# 15  8.241442e+04  1.381511  8.241442e+04 -1.138564e+05      leaf
# 16  3.919371e+02  1.364256  3.919371e+02 -5.347024e+02      leaf
# 17  6.240768e+04  0.000000  6.240768e+04 -8.586076e+04  internal
# 18  6.210718e+04  0.000000  6.210718e+04 -8.545393e+04  internal
# 19  3.005031e+02  1.353837  3.005031e+02 -4.068321e+02      leaf
# 20  5.453003e+04  0.000000  5.453003e+04 -7.500191e+04  internal
# 21  7.577151e+03  1.379412  7.577151e+03 -1.045202e+04      leaf
# 22  4.934934e+04  1.374947  4.934934e+04 -6.785272e+04      leaf
# 23  5.180688e+03  1.379970  5.180688e+03 -7.149193e+03      leaf
# 24  4.729947e+04  0.000000  4.729947e+04 -6.472789e+04  internal
# 25  4.706666e+04  0.000000  4.706666e+04 -6.441637e+04  internal

# %%
(model_structure2.G == 0).sum()
# Out:
# 0

# %%
model_structure2.loc[model_structure2.node_type == 'internal', 'weight'] = \
    - model_structure2.loc[model_structure2.node_type == 'internal', 'G'] / \
    model_structure2.loc[model_structure2.node_type == 'internal', 'H']

# %%
model_structure2.head(26)
# Out:
#     index  tree  node  yes   no  missing split_var  split_point   quality  \
# 0       0     0     0  NaN  NaN      NaN       NaN          NaN  0.299507
# 1       1     1     0  NaN  NaN      NaN       NaN          NaN  0.299335
# 2       2     2     0  NaN  NaN      NaN       NaN          NaN  0.299103
# 3       3     3     0  NaN  NaN      NaN       NaN          NaN  0.298790
# 4       4     4     0  NaN  NaN      NaN       NaN          NaN  0.298368
# 5       5     5     0  NaN  NaN      NaN       NaN          NaN  0.297801
# 6       6     6     0  NaN  NaN      NaN       NaN          NaN  0.297038
# 7       7     7     0  NaN  NaN      NaN       NaN          NaN  0.296014
# 8       8     8     0  NaN  NaN      NaN       NaN          NaN  0.294641
# 9       9     9     0  NaN  NaN      NaN       NaN          NaN  0.292804
# 10     10    10     0  NaN  NaN      NaN       NaN          NaN  0.290357
# 11     11    11     0  1.0  2.0      1.0       f29          0.5  0.093750
# 12     12    11     1  NaN  NaN      NaN       NaN          NaN  0.287167
# 13     13    11     2  NaN  NaN      NaN       NaN          NaN  0.273858
# 14     14    12     0  1.0  2.0      1.0       f29          0.5  0.406250
# 15     15    12     1  NaN  NaN      NaN       NaN          NaN  0.282899
# 16     16    12     2  NaN  NaN      NaN       NaN          NaN  0.265643
# 17     17    13     0  1.0  2.0      1.0       f29          0.5  0.773438
# 18     18    13     1  3.0  4.0      3.0       f33         81.5  0.316406
# 19     23    13     2  NaN  NaN      NaN       NaN          NaN  0.255224
# 20     19    13     3  5.0  6.0      5.0       f24          0.5  0.464844
# 21     22    13     4  NaN  NaN      NaN       NaN          NaN  0.280800
# 22     20    13     5  NaN  NaN      NaN       NaN          NaN  0.276335
# 23     21    13     6  NaN  NaN      NaN       NaN          NaN  0.281357
# 24     24    14     0  1.0  2.0      1.0       f29          0.5  1.187500
# 25     25    14     1  3.0  4.0      3.0       f33         81.5  0.675781
#
#            cover    weight             H             G node_type
# 0   2.885251e+06  1.398119  2.885251e+06 -4.033925e+06      leaf
# 1   2.138500e+06  1.397947  2.138500e+06 -2.989511e+06      leaf
# 2   1.585294e+06  1.397715  1.585294e+06 -2.215790e+06      leaf
# 3   1.175469e+06  1.397402  1.175469e+06 -1.642603e+06      leaf
# 4   8.718635e+05  1.396981  8.718635e+05 -1.217976e+06      leaf
# 5   6.469472e+05  1.396413  6.469472e+05 -9.034057e+05      leaf
# 6   4.803253e+05  1.395651  4.803253e+05 -6.703663e+05      leaf
# 7   3.568892e+05  1.394626  3.568892e+05 -4.977270e+05      leaf
# 8   2.654460e+05  1.393253  2.654460e+05 -3.698335e+05      leaf
# 9   1.977039e+05  1.391417  1.977039e+05 -2.750886e+05      leaf
# 10  1.475204e+05  1.388969  1.475204e+05 -2.049013e+05      leaf
# 11  1.103448e+05  1.385718  1.103448e+05 -1.529067e+05  internal
# 12  1.098294e+05  1.385780  1.098294e+05 -1.521993e+05      leaf
# 13  5.154083e+02  1.372470  5.154083e+02 -7.073825e+02      leaf
# 14  8.280636e+04  1.381429  8.280636e+04 -1.143911e+05  internal
# 15  8.241442e+04  1.381511  8.241442e+04 -1.138564e+05      leaf
# 16  3.919371e+02  1.364256  3.919371e+02 -5.347024e+02      leaf
# 17  6.240768e+04  1.375804  6.240768e+04 -8.586076e+04  internal
# 18  6.210718e+04  1.375911  6.210718e+04 -8.545393e+04  internal
# 19  3.005031e+02  1.353837  3.005031e+02 -4.068321e+02      leaf
# 20  5.453003e+04  1.375424  5.453003e+04 -7.500191e+04  internal
# 21  7.577151e+03  1.379412  7.577151e+03 -1.045202e+04      leaf
# 22  4.934934e+04  1.374947  4.934934e+04 -6.785272e+04      leaf
# 23  5.180688e+03  1.379970  5.180688e+03 -7.149193e+03      leaf
# 24  4.729947e+04  1.368470  4.729947e+04 -6.472789e+04  internal
# 25  4.706666e+04  1.368620  4.706666e+04 -6.441637e+04  internal

# %%
preds2 = bst.predict(dtest, ntree_limit = 1)

# %%
preds2[:5]
# Out:
# array([4.0475802, 4.0475802, 4.0475802, 4.0475802, 4.0475802],
#       dtype=float32)

# %%
np.exp(1.398119)
# Out:
# 4.0475793051862565

# %%
preds3 = bst.predict(dtest, ntree_limit = 2)

# %%
preds3[:5]
# Out:
# array([5.460029, 5.460029, 5.460029, 5.460029, 5.460029], dtype=float32)

# %%
np.exp(1.398119+1.3979470-np.log(3))
# Out:
# 5.4600268718660425

# %%
preds4 = bst.predict(dtest, ntree_limit = 3)

# %%
preds4[:5]
# Out:
# array([7.3636575, 7.3636575, 7.3636575, 7.3636575, 7.3636575],
#       dtype=float32)

# %%
np.exp(1.398119+1.3979470-np.log(3)+1.397715-np.log(3))
# Out:
# 7.363655073111648

# %%
preds5 = bst.predict(dtest, ntree_limit = 11)

# %%
preds5[:5]
# Out:
# array([78.442825, 78.442825, 78.442825, 78.442825, 78.442825],
#       dtype=float32)

# %%
dtest

# %%
data[4741:4747, 29]
# Out:
# array([0., 0., 0., 0., 0., 0.])

# %%
np.exp(model_structure2.loc[(model_structure2.tree <= 10), 'weight'].sum() - (10*np.log(3)))
# Out:
# 78.4428162301013

# %%
model_structure2.loc[(model_structure2.tree <= 10), 'weight'].sum() - (10*np.log(3))
# Out:
# 4.362369903668112

# %%
preds6 = bst.predict(dtest, ntree_limit = 12)

# %%
preds6[:5]
# Out:
# array([104.53664, 104.53664, 104.53664, 104.53664, 104.53664],
#       dtype=float32)

# %%
1.385718-np.log(3)
# Out:
# 0.2871057113318902

# %%
1.385780-np.log(3)
# Out:
# 0.28716771133189023

# %%
np.exp(4.362369903668112+0.28716771133189023)
# Out:
# 104.53663822696451

# %%
len(model_structure2.loc[(model_structure2.index <= 11) &(model_structure2.node < 2), 'weight'])
# Out:
# 12

# %%
model_structure2.loc[(model_structure2.tree <= 11) &(model_structure2.node < 2)]
# Out:
#     index  tree  node  yes   no  missing split_var  split_point   quality  \
# 0       0     0     0  NaN  NaN      NaN       NaN          NaN  0.299507
# 1       1     1     0  NaN  NaN      NaN       NaN          NaN  0.299335
# 2       2     2     0  NaN  NaN      NaN       NaN          NaN  0.299103
# 3       3     3     0  NaN  NaN      NaN       NaN          NaN  0.298790
# 4       4     4     0  NaN  NaN      NaN       NaN          NaN  0.298368
# 5       5     5     0  NaN  NaN      NaN       NaN          NaN  0.297801
# 6       6     6     0  NaN  NaN      NaN       NaN          NaN  0.297038
# 7       7     7     0  NaN  NaN      NaN       NaN          NaN  0.296014
# 8       8     8     0  NaN  NaN      NaN       NaN          NaN  0.294641
# 9       9     9     0  NaN  NaN      NaN       NaN          NaN  0.292804
# 10     10    10     0  NaN  NaN      NaN       NaN          NaN  0.290357
# 11     11    11     0  1.0  2.0      1.0       f29          0.5  0.093750
# 12     12    11     1  NaN  NaN      NaN       NaN          NaN  0.287167
#
#           cover    weight            H             G node_type
# 0   2885250.750  1.398119  2885250.750 -4.033925e+06      leaf
# 1   2138500.500  1.397947  2138500.500 -2.989511e+06      leaf
# 2   1585294.380  1.397715  1585294.380 -2.215790e+06      leaf
# 3   1175469.250  1.397402  1175469.250 -1.642603e+06      leaf
# 4    871863.500  1.396981   871863.500 -1.217976e+06      leaf
# 5    646947.188  1.396413   646947.188 -9.034057e+05      leaf
# 6    480325.344  1.395651   480325.344 -6.703663e+05      leaf
# 7    356889.188  1.394626   356889.188 -4.977270e+05      leaf
# 8    265446.031  1.393253   265446.031 -3.698335e+05      leaf
# 9    197703.938  1.391417   197703.938 -2.750886e+05      leaf
# 10   147520.406  1.388969   147520.406 -2.049013e+05      leaf
# 11   110344.781  1.385718   110344.781 -1.529067e+05  internal
# 12   109829.375  1.385780   109829.375 -1.521993e+05      leaf

# %%
np.log(3)
# Out:
# 1.0986122886681098

# %%
trees_G = model_structure[['tree', 'node', 'G']].copy()

# %%
trees_G.columns = ['tree_yes', 'node_yes', 'G_yes']

# %%
trees_G.head()
# Out:
#    tree_yes  node_yes         G_yes
# 0         0         0 -2.306778e+06
# 1         1         0 -1.709378e+06
# 2         2         0 -1.266813e+06
# 3         3         0 -9.389528e+05
# 4         4         0 -6.960682e+05

# %%
model_structure = model_structure.merge(trees_G,
                                        how = 'left',
                                        left_on = ['tree', 'yes'],
                                        right_on = ['tree_yes', 'node_yes'])

# %%
model_structure.head(20)
# Out:
#     index  tree  node  yes   no  missing split_var  split_point   quality  \
# 0       0     0     0  NaN  NaN      NaN       NaN          NaN  0.299507
# 1       1     1     0  NaN  NaN      NaN       NaN          NaN  0.299335
# 2       2     2     0  NaN  NaN      NaN       NaN          NaN  0.299103
# 3       3     3     0  NaN  NaN      NaN       NaN          NaN  0.298790
# 4       4     4     0  NaN  NaN      NaN       NaN          NaN  0.298368
# 5       5     5     0  NaN  NaN      NaN       NaN          NaN  0.297801
# 6       6     6     0  NaN  NaN      NaN       NaN          NaN  0.297038
# 7       7     7     0  NaN  NaN      NaN       NaN          NaN  0.296014
# 8       8     8     0  NaN  NaN      NaN       NaN          NaN  0.294641
# 9       9     9     0  NaN  NaN      NaN       NaN          NaN  0.292804
# 10     10    10     0  NaN  NaN      NaN       NaN          NaN  0.290357
# 11     11    11     0  1.0  2.0      1.0       f29          0.5  0.093750
# 12     12    11     1  NaN  NaN      NaN       NaN          NaN  0.287167
# 13     13    11     2  NaN  NaN      NaN       NaN          NaN  0.273858
# 14     14    12     0  1.0  2.0      1.0       f29          0.5  0.406250
# 15     15    12     1  NaN  NaN      NaN       NaN          NaN  0.282899
# 16     16    12     2  NaN  NaN      NaN       NaN          NaN  0.265643
# 17     17    13     0  1.0  2.0      1.0       f29          0.5  0.773438
# 18     18    13     1  3.0  4.0      3.0       f33         81.5  0.316406
# 19     23    13     2  NaN  NaN      NaN       NaN          NaN  0.255224
#
#            cover    weight             H             G  tree_yes  node_yes  \
# 0   2.885251e+06  0.799507  2.885251e+06 -2.306778e+06       NaN       NaN
# 1   2.138500e+06  0.799335  2.138500e+06 -1.709378e+06       NaN       NaN
# 2   1.585294e+06  0.799103  1.585294e+06 -1.266813e+06       NaN       NaN
# 3   1.175469e+06  0.798790  1.175469e+06 -9.389528e+05       NaN       NaN
# 4   8.718635e+05  0.798368  8.718635e+05 -6.960682e+05       NaN       NaN
# 5   6.469472e+05  0.797801  6.469472e+05 -5.161352e+05       NaN       NaN
# 6   4.803253e+05  0.797038  4.803253e+05 -3.828377e+05       NaN       NaN
# 7   3.568892e+05  0.796014  3.568892e+05 -2.840888e+05       NaN       NaN
# 8   2.654460e+05  0.794641  2.654460e+05 -2.109342e+05       NaN       NaN
# 9   1.977039e+05  0.792804  1.977039e+05 -1.567406e+05       NaN       NaN
# 10  1.475204e+05  0.790357  1.475204e+05 -1.165937e+05       NaN       NaN
# 11  1.103448e+05  0.000000  1.103448e+05  0.000000e+00      11.0       1.0
# 12  1.098294e+05  0.787167  1.098294e+05 -8.645411e+04       NaN       NaN
# 13  5.154083e+02  0.773858  5.154083e+02 -3.988528e+02       NaN       NaN
# 14  8.280636e+04  0.000000  8.280636e+04  0.000000e+00      12.0       1.0
# 15  8.241442e+04  0.782899  8.241442e+04 -6.452216e+04       NaN       NaN
# 16  3.919371e+02  0.765643  3.919371e+02 -3.000840e+02       NaN       NaN
# 17  6.240768e+04  0.000000  6.240768e+04  0.000000e+00      13.0       1.0
# 18  6.210718e+04  0.000000  6.210718e+04  0.000000e+00      13.0       3.0
# 19  3.005031e+02  0.755224  3.005031e+02 -2.269473e+02       NaN       NaN
#
#            G_yes
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11 -86454.113447
# 12           NaN
# 13           NaN
# 14 -64522.155552
# 15           NaN
# 16           NaN
# 17      0.000000
# 18      0.000000
# 19           NaN

# %%
trees_G.columns = ['tree_no', 'node_no', 'G_no']

# %%
model_structure = model_structure.merge(trees_G,
                                        how = 'left',
                                        left_on = ['tree', 'no'],
                                        right_on = ['tree_no', 'node_no'])

# %%
model_structure.head(26)
# Out:
#     index  tree  node  yes   no  missing split_var  split_point   quality  \
# 0       0     0     0  NaN  NaN      NaN       NaN          NaN  0.299507
# 1       1     1     0  NaN  NaN      NaN       NaN          NaN  0.299335
# 2       2     2     0  NaN  NaN      NaN       NaN          NaN  0.299103
# 3       3     3     0  NaN  NaN      NaN       NaN          NaN  0.298790
# 4       4     4     0  NaN  NaN      NaN       NaN          NaN  0.298368
# 5       5     5     0  NaN  NaN      NaN       NaN          NaN  0.297801
# 6       6     6     0  NaN  NaN      NaN       NaN          NaN  0.297038
# 7       7     7     0  NaN  NaN      NaN       NaN          NaN  0.296014
# 8       8     8     0  NaN  NaN      NaN       NaN          NaN  0.294641
# 9       9     9     0  NaN  NaN      NaN       NaN          NaN  0.292804
# 10     10    10     0  NaN  NaN      NaN       NaN          NaN  0.290357
# 11     11    11     0  1.0  2.0      1.0       f29          0.5  0.093750
# 12     12    11     1  NaN  NaN      NaN       NaN          NaN  0.287167
# 13     13    11     2  NaN  NaN      NaN       NaN          NaN  0.273858
# 14     14    12     0  1.0  2.0      1.0       f29          0.5  0.406250
# 15     15    12     1  NaN  NaN      NaN       NaN          NaN  0.282899
# 16     16    12     2  NaN  NaN      NaN       NaN          NaN  0.265643
# 17     17    13     0  1.0  2.0      1.0       f29          0.5  0.773438
# 18     18    13     1  3.0  4.0      3.0       f33         81.5  0.316406
# 19     23    13     2  NaN  NaN      NaN       NaN          NaN  0.255224
# 20     19    13     3  5.0  6.0      5.0       f24          0.5  0.464844
# 21     22    13     4  NaN  NaN      NaN       NaN          NaN  0.280800
# 22     20    13     5  NaN  NaN      NaN       NaN          NaN  0.276335
# 23     21    13     6  NaN  NaN      NaN       NaN          NaN  0.281357
# 24     24    14     0  1.0  2.0      1.0       f29          0.5  1.187500
# 25     25    14     1  3.0  4.0      3.0       f33         81.5  0.675781
#
#            cover    weight             H             G  tree_yes  node_yes  \
# 0   2.885251e+06  0.799507  2.885251e+06 -2.306778e+06       NaN       NaN
# 1   2.138500e+06  0.799335  2.138500e+06 -1.709378e+06       NaN       NaN
# 2   1.585294e+06  0.799103  1.585294e+06 -1.266813e+06       NaN       NaN
# 3   1.175469e+06  0.798790  1.175469e+06 -9.389528e+05       NaN       NaN
# 4   8.718635e+05  0.798368  8.718635e+05 -6.960682e+05       NaN       NaN
# 5   6.469472e+05  0.797801  6.469472e+05 -5.161352e+05       NaN       NaN
# 6   4.803253e+05  0.797038  4.803253e+05 -3.828377e+05       NaN       NaN
# 7   3.568892e+05  0.796014  3.568892e+05 -2.840888e+05       NaN       NaN
# 8   2.654460e+05  0.794641  2.654460e+05 -2.109342e+05       NaN       NaN
# 9   1.977039e+05  0.792804  1.977039e+05 -1.567406e+05       NaN       NaN
# 10  1.475204e+05  0.790357  1.475204e+05 -1.165937e+05       NaN       NaN
# 11  1.103448e+05  0.000000  1.103448e+05  0.000000e+00      11.0       1.0
# 12  1.098294e+05  0.787167  1.098294e+05 -8.645411e+04       NaN       NaN
# 13  5.154083e+02  0.773858  5.154083e+02 -3.988528e+02       NaN       NaN
# 14  8.280636e+04  0.000000  8.280636e+04  0.000000e+00      12.0       1.0
# 15  8.241442e+04  0.782899  8.241442e+04 -6.452216e+04       NaN       NaN
# 16  3.919371e+02  0.765643  3.919371e+02 -3.000840e+02       NaN       NaN
# 17  6.240768e+04  0.000000  6.240768e+04  0.000000e+00      13.0       1.0
# 18  6.210718e+04  0.000000  6.210718e+04  0.000000e+00      13.0       3.0
# 19  3.005031e+02  0.755224  3.005031e+02 -2.269473e+02       NaN       NaN
# 20  5.453003e+04  0.000000  5.453003e+04  0.000000e+00      13.0       5.0
# 21  7.577151e+03  0.780800  7.577151e+03 -5.916240e+03       NaN       NaN
# 22  4.934934e+04  0.776335  4.934934e+04 -3.831160e+04       NaN       NaN
# 23  5.180688e+03  0.781357  5.180688e+03 -4.047969e+03       NaN       NaN
# 24  4.729947e+04  0.000000  4.729947e+04  0.000000e+00      14.0       1.0
# 25  4.706666e+04  0.000000  4.706666e+04  0.000000e+00      14.0       3.0
#
#            G_yes  tree_no  node_no         G_no
# 0            NaN      NaN      NaN          NaN
# 1            NaN      NaN      NaN          NaN
# 2            NaN      NaN      NaN          NaN
# 3            NaN      NaN      NaN          NaN
# 4            NaN      NaN      NaN          NaN
# 5            NaN      NaN      NaN          NaN
# 6            NaN      NaN      NaN          NaN
# 7            NaN      NaN      NaN          NaN
# 8            NaN      NaN      NaN          NaN
# 9            NaN      NaN      NaN          NaN
# 10           NaN      NaN      NaN          NaN
# 11 -86454.113447     11.0      2.0  -398.852753
# 12           NaN      NaN      NaN          NaN
# 13           NaN      NaN      NaN          NaN
# 14 -64522.155552     12.0      2.0  -300.084017
# 15           NaN      NaN      NaN          NaN
# 16           NaN      NaN      NaN          NaN
# 17      0.000000     13.0      2.0  -226.947267
# 18      0.000000     13.0      4.0 -5916.239968
# 19           NaN      NaN      NaN          NaN
# 20 -38311.596223     13.0      6.0 -4047.969090
# 21           NaN      NaN      NaN          NaN
# 22           NaN      NaN      NaN          NaN
# 23           NaN      NaN      NaN          NaN
# 24      0.000000     14.0      2.0     0.000000
# 25      0.000000     14.0      4.0     0.000000

# %%
  xgb_trees[Feature != 'Leaf', G := G_yes + G_no]
  
  xgb_trees[Feature != 'Leaf', weight := - G / H]
